# %%
#covid19_cleaned_8_10.csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DF=pd.read_csv("covid19_cleaned_8_10.zip",low_memory = False)
y=np.array(DF["deceased"]) 
x=np.array(DF[["age",'chronic_disease_binary','travel_history_binary']])

# %%
len(x)# make sure lel(x) and len(y) must be the same
# Out:
# 2309996

# %%
len(y)
# Out:
# 2309996

# %%
DF.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'age', 'sex', 'city', 'province', 'country',
#        'latitude', 'longitude', 'date_onset_symptoms',
#        'date_admission_hospital', 'date_confirmation', 'symptoms',
#        'travel_history_dates', 'travel_history_location',
#        'reported_market_exposure', 'chronic_disease_binary', 'chronic_disease',
#        'outcome', 'date_death_or_discharge', 'admin3', 'admin2', 'admin1',
#        'travel_history_binary', 'hospitalized', 'deceased', 'fever', 'cough',
#        'fatigue', 'headache', 'dizziness', 'sore throat', 'pneumonia',
#        'respiratory', 'nausea', 'diarrhea', 'severe_r'],
#       dtype='object')

# %%
DF['deceased']
# Out:
# 0          0
# 1          1
# 2          0
# 3          0
# 4          0
#           ..
# 2309991    0
# 2309992    0
# 2309993    0
# 2309994    0
# 2309995    0
# Name: deceased, Length: 2309996, dtype: int64

# %%
DF.age.tolist()
# Out:
# [49.09022890701642,
#  78.0,
#  61.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  66.0,
#  27.0,
#  17.0,
#  51.0,
#  68.0,
#  26.0,
#  30.0,
#  53.0,
#  35.0,
#  49.09022890701642,
#  27.0,
#  28.0,
#  58.0,
#  33.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  33.0,
#  50.0,
#  33.0,
#  45.0,
#  24.0,
#  88.0,
#  49.09022890701642,
#  29.0,
#  21.0,
#  78.0,
#  52.0,
#  60.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  28.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  56.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  79.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  50.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  26.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  60.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  44.5,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  82.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  25.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  40.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  24.5,
#  49.09022890701642,
#  64.5,
#  64.5,
#  64.5,
#  64.5,
#  64.5,
#  64.5,
#  64.5,
#  44.5,
#  64.5,
#  84.5,
#  49.09022890701642,
#  54.5,
#  24.5,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  16.0,
#  64.5,
#  34.5,
#  54.5,
#  54.5,
#  43.0,
#  49.09022890701642,
#  64.5,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  33.0,
#  7.0,
#  33.0,
#  7.0,
#  44.0,
#  69.0,
#  16.0,
#  47.0,
#  49.09022890701642,
#  35.0,
#  8.0,
#  43.0,
#  10.0,
#  55.0,
#  47.0,
#  25.0,
#  47.0,
#  38.0,
#  30.0,
#  49.09022890701642,
#  26.0,
#  47.0,
#  42.0,
#  34.0,
#  62.0,
#  39.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  29.0,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  49.09022890701642,
#  ...]

# %%
# logistic looking at age =x we will predict y= dead or hospitalised 
from sklearn.linear_model import LogisticRegression as LR
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
y=y.ravel() #we are expecting y.shape to be (,2309996)

# %%
y.shape
# Out:
# (2309996,)

# %%
#x=x.reshape(-1,1)

# %%
# Make your x is my age=x two dementional
#x=x.reshape(-1,1) 
#y=y.ravel() # my y was (n,2) I had to make it into 1D
#y.shapey.shape
x.shape
# Out:
# (2309996, 3)

# %%
# make sure it is ( 2309996,1)

# %%
model=LR() # Logistic Regression 
xtrain,xtest,ytrain,ytest=train_test_split(x,y)
model.fit(xtrain,ytrain) # Doing LOgistic Model my training data 
yp=model.predict(xtest) # tell the prediction, using xtest 
accuracy_score(ytest,yp) # ytest real values of xtest, yp is model using train
# Below we can see what is the percenttage of accuracy of predicting looking at x (age) will be y (deseased)
# Out:
# 0.9977679615029637

# %%
ACCS=[] # how important is the randomization?
for j in range(25):
    model=LR()
    xtrain,xtest,ytrain,ytest=train_test_split(x,y)
    model.fit(xtrain,ytrain)
    YP=model.predict(xtest)
    ACCS.append(accuracy_score(ytest,YP)) # make a list of all 25 running model
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-cdc9d8eace9b> in <module>
#       3     model=LR()
#       4     xtrain,xtest,ytrain,ytest=train_test_split(x,y)
# ----> 5     model.fit(xtrain,ytrain)
#       6     YP=model.predict(xtest)
#       7     ACCS.append(accuracy_score(ytest,YP)) # make a list of all 25 running model
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1599                       penalty=penalty, max_squared_sum=max_squared_sum,
#    1600                       sample_weight=sample_weight)
# -> 1601             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1602
#    1603         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     934                 func, w0, method="L-BFGS-B", jac=True,
#     935                 args=(X, target, 1. / C, sample_weight),
# --> 936                 options={"iprint": iprint, "gtol": tol, "maxiter": max_iter}
#     937             )
#     938             n_iter_i = _check_optimize_result(
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608     elif meth == 'l-bfgs-b':
#     609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#     612         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     293     else:
#     294         def func_and_grad(x):
# --> 295             f = fun(x, *args)
#     296             g = jac(x, *args)
#     297             return f, g
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      63     def __call__(self, x, *args):
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#      67         return fg[0]
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in _logistic_loss_and_grad(w, X, y, alpha, sample_weight)
#     122
#     123     # Logistic loss is the negative of the log of the logistic function.
# --> 124     out = -np.sum(sample_weight * log_logistic(yz)) + .5 * alpha * np.dot(w, w)
#     125
#     126     z = expit(yz)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\extmath.py in log_logistic(X, out)
#     579
#     580     if is_1d:
# --> 581         return np.squeeze(out)
#     582     return out
#     583
#
# KeyboardInterrupt:

# %%
plt.boxplot(ACCS,vert=False);
plt.title("Accuracy for AGE") # Looking at age we can tell what is the percentage of the person taht going to be desseased
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4c43730f8d93> in <module>
# ----> 1 plt.boxplot(ACCS,vert=False);
#       2 plt.title("Accuracy for AGE") # Looking at age we can tell what is the percentage of the person taht going to be desseased
#
# NameError: name 'ACCS' is not defined

# %%
from sklearn.model_selection import cross_validate

# %%
cross_validate(LR(), x, y, cv=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7779f64d66ba> in <module>
# ----> 1 cross_validate(LR(), x, y, cv=5)
#
# NameError: name 'cross_validate' is not defined

# %%
# Logistic model, 
mymodel=LR()
xtrain,xtest,ytrain,ytest=train_test_split(x,y)# split the data into train and test 
mymodel.fit(xtrain,ytrain)
ypredict=mymodel.predict(xtest)

# %%
probabilities=mymodel.predict_proba(xtest) [:,1]# all rows and second columns

# %%
# import the ROC curve Package 
from sklearn.metrics import roc_curve

# %%
FPR, TPR, THRESHOLD = roc_curve(ytest, probabilities)# False Positive Ratio, True Positive Ratio

# %%
plt.plot(FPR,TPR,c="red")
plt.plot([0,1],[0,1],c="k",ls="--")
plt.grid()
plt.xlabel("False Positive Rate",fontsize=14)
plt.ylabel("True Positive Rate",fontsize=14)
plt.gcf().set_size_inches(6,6) 
# Higher  the corve is better accuracy , prediction  NOT GOOD??????

# %%
fig,ax=plt.subplots(nrows=1,ncols=1)
for j in range(10):
    mymodel = LR()
    xtrain,xtest,ytrain,ytest=train_test_split(x,y)
    
    mymodel.fit(xtrain,ytrain)
    probs=mymodel.predict_proba(xtest)[:,1]
    FPR,TPR,THRESHOLDS=roc_curve(ytest,probs)
    ax.plot(FPR,TPR)
    
ax.grid()
ax.plot([0,1],[0,1],c="k",ls="--") # 45 degree dashed black line
ax.set_xlabel("False Positives")
ax.set_ylabel("True Positives")
ax.set_title("Covid-19 First 1000 Cases: Age vs Deceased 10 Train/Test Splits")
fig.set_size_inches(6,6)

# %% [markdown]
# ## Leave one out cross validation

# %%
# Leave One out cross valdation 
import matplotlib.pyplot as plt
import sklearn

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import LeavePOut
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

#loocv = model_selection.LeaveOneOut() # Leave One out CV
#model_loocv = LogisticRegression()
#results_loocv = model_selection.cross_val_score(model_loocv, x, y, cv=loocv)
#print("Accuracy: %.2f%%" % (results_loocv.mean()*100.0))

# %% [markdown]
# ## conclusion :
# The mean accuracy for the model using the leave-one-out cross-validation is ___%  percent.

# %%
DF.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'age', 'sex', 'city', 'province', 'country',
#        'latitude', 'longitude', 'date_onset_symptoms',
#        'date_admission_hospital', 'date_confirmation', 'symptoms',
#        'travel_history_dates', 'travel_history_location',
#        'reported_market_exposure', 'chronic_disease_binary', 'chronic_disease',
#        'outcome', 'date_death_or_discharge', 'admin3', 'admin2', 'admin1',
#        'travel_history_binary', 'hospitalized', 'deceased', 'fever', 'cough',
#        'fatigue', 'headache', 'dizziness', 'sore throat', 'pneumonia',
#        'respiratory', 'nausea', 'diarrhea', 'severe_r'],
#       dtype='object')

# %%
DF['sex']=DF['sex'].apply(lambda x: 0 if x =='female' else 1)

# %%
DF.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
Y=DF["sex"] # my target using almost all features 
np.unique(Y,return_counts=True) # So there is 1158473 zeros and ..
# Out:
# (array(['female', 'male'], dtype=object),
#  array([1158473, 1151523], dtype=int64))

# %%
#DF2 = pd.get_dummies(DF2,columns=["country"])
DF["country"].isna().sum()
# Out:
# 0

# %%
dummies = pd.get_dummies(DF,columns=["country"])# turn country column into dummies

# %%
dummies.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'age', 'sex', 'city', 'province', 'latitude',
#        'longitude', 'date_onset_symptoms', 'date_admission_hospital',
#        ...
#        'country_Ukraine', 'country_United Arab Emirates',
#        'country_United Kingdom', 'country_United States', 'country_Uruguay',
#        'country_Venezuela', 'country_Vietnam', 'country_Virgin Islands, U.S.',
#        'country_Zambia', 'country_Zimbabwe'],
#       dtype='object', length=179)

# %%
dropcols=DF[['Unnamed: 0','ID','city', 'province','latitude', 'longitude', 'date_onset_symptoms','date_admission_hospital','travel_history_dates', 'travel_history_location','reported_market_exposure','chronic_disease','outcome', 'date_death_or_discharge', 'admin3', 'admin2', 'admin1','fever', 'cough','fatigue', 'headache', 'dizziness', 'sore throat', 'pneumonia','respiratory', 'nausea', 'diarrhea', 'severe_r']]
# DO NOT FOGET TO DRROP YOUR TARGET
DF.head()
# Out:
#    Unnamed: 0           ID        age     sex            city   province  \
# 0           0      000-1-1  49.090229    male        Shek Lei  Hong Kong
# 1           1     000-1-10  78.000000    male      Vo Euganeo     Veneto
# 2           2    000-1-100  61.000000  female             NaN        NaN
# 3           3   000-1-1000  49.090229    male  Zhengzhou City      Henan
# 4           4  000-1-10000  49.090229    male  Pingxiang City    Jiangxi
#
#      country   latitude   longitude date_onset_symptoms  ... cough fatigue  \
# 0      China  22.365019  114.133808                 NaN  ...   NaN     NaN
# 1      Italy  45.297748   11.658382                 NaN  ...   NaN     NaN
# 2  Singapore   1.353460  103.815100                 NaN  ...   NaN     NaN
# 3      China  34.629310  113.468000                 NaN  ...   NaN     NaN
# 4      China  27.513560  113.902900                 NaN  ...   NaN     NaN
#
#   headache dizziness sore throat pneumonia  respiratory nausea diarrhea  \
# 0      NaN       NaN         NaN       NaN          NaN    NaN      NaN
# 1      NaN       NaN         NaN       NaN          NaN    NaN      NaN
# 2      NaN       NaN         NaN       NaN          NaN    NaN      NaN
# 3      NaN       NaN         NaN       NaN          NaN    NaN      NaN
# 4      NaN       NaN         NaN       NaN          NaN    NaN      NaN
#
#   severe_r
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 37 columns]

# %%
#X=np.array(DF.drop(columns=dropcols)) # My x columns are AGE, CHRONIC DESEASE,COUNRTY,TRAVEL_HISTORY_BINARY,HOSPIT,DECEASED

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPClassifier as ANN
from sklearn.metrics import accuracy_score, roc_curve
from sklearn.model_selection import train_test_split

# %%
# SCALE MY X standartize 
#scaler=MinMaxScaler()
#XScaled=scaler.fit_transform(X)
DF["travel_history_binary"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ## NNA predict sex using "age","chronic_disease_binary","hospitalized","deceased","travel_history_binary"]],dummies],axis=1)
# dummies are country

# %%
xvals=["age","chronic_disease_binary","hospitalized","deceased","travel_history_binary"]

# X=np.array(pd.concat([DF[["age","chronic_disease_binary","hospitalized","deceased","travel_history_binary"]],
                      #dummies],axis=1))
xscal=DF[xvals]
# I want to scale first all those numerical ones then concatinate with dummies 
#scaler=MinMaxScaler()
#XScaled=scaler.fit_transform(xscal)
#X=pd.concat([XScaled,dummies],axis=1)

# %%
y=np.array(DF["sex"])

# %%
X=np.array(pd.concat([DF[["age","chronic_disease_binary","hospitalized","deceased","travel_history_binary"]],
                      dummies],axis=1))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-27-bfea48191f7a> in <module>
#       1 X=np.array(pd.concat([DF[["age","chronic_disease_binary","hospitalized","deceased","travel_history_binary"]],
# ----> 2                       dummies],axis=1))
#
# MemoryError: Unable to allocate 3.17 GiB for an array with shape (2309996, 184) and data type object

# %%
DF.dtypes
# Out:
# Unnamed: 0                    int64
# ID                           object
# age                         float64
# sex                          object
# city                         object
# province                     object
# country                      object
# latitude                    float64
# longitude                   float64
# date_onset_symptoms          object
# date_admission_hospital      object
# date_confirmation            object
# symptoms                     object
# travel_history_dates         object
# travel_history_location      object
# reported_market_exposure     object
# chronic_disease_binary        int64
# chronic_disease              object
# outcome                      object
# date_death_or_discharge      object
# admin3                       object
# admin2                       object
# admin1                       object
# travel_history_binary         int64
# hospitalized                  int64
# deceased                      int64
# fever                       float64
# cough                       float64
# fatigue                     float64
# headache                    float64
# dizziness                   float64
# sore throat                 float64
# pneumonia                   float64
# respiratory                 float64
# nausea                      float64
# diarrhea                    float64
# severe_r                    float64
# dtype: object

# %%
noAges = DF[np.logical_and(DF["age"]>=49.0, DF["age"]<=49.1)]

# %%
Y = np.array(noAges["sex"])

# %%
from sklearn.neural_network import MLPClassifier as ANN
from sklearn.metrics import accuracy_score, roc_curve
from sklearn.model_selection import train_test_split

# %%
# Single train test split
model=ANN(hidden_layer_sizes=(16,8,4), max_iter=2)
xtrain,xtest,ytrain,ytest=train_test_split(noAges, Y) # I am using x standardized 
model.fit(xtrain,ytrain)
YP=model.predict(xtest)
print(accuracy_score(ytest,YP))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f8501cc6335d> in <module>
#       1 # Single train test split
# ----> 2 model=ANN(hidden_layer_sizes=(16,8,4), max_iter=2)
#       3 xtrain,xtest,ytrain,ytest=train_test_split(noAges, Y) # I am using x standardized
#       4 model.fit(xtrain,ytrain)
#       5 YP=model.predict(xtest)
#
# NameError: name 'ANN' is not defined

# %%
model=ANN(hidden_layer_sizes=(16,8,4), max_iter=10)
acc=[]
for repeat in range(10):
    xtrain,xtest,ytrain,ytest=train_test_split(X, Y) # I am using x standardized 
    model.fit(xtrain,ytrain)
    YP=model.predict(xtest)
    print(accuracy_score(ytest,YP))
    acc.append(accuracy_score(ytest,YP))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c07e21eaeac6> in <module>
#       2 acc=[]
#       3 for repeat in range(10):
# ----> 4     xtrain,xtest,ytrain,ytest=train_test_split(X, Y) # I am using x standardized
#       5     model.fit(xtrain,ytrain)
#       6     YP=model.predict(xtest)
#
# NameError: name 'X' is not defined

# %%
#plt.boxplot(acc, vert=False)
#plt.grid()
#plt.gcf().set_size_inches(10,2)
